# %% [markdown]
# <a href="https://colab.research.google.com/github/Userfrom1995/SubtitleGenerator/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yt_dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 59.3 MB/s eta 0:00:00
# ...

# %%
import yt_dlp

def download_youtube_video(url, output_path="."):
    ydl_opts = {
        'format': 'best',
        'outtmpl': f'{output_path}/ap.%(ext)s',
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])

if __name__ == "__main__":
    video_url = "https://youtu.be/Rb7kZeztbf4?si=P1oxMCZUn84htNa1"  # Replace with your video URL
    download_youtube_video(video_url, output_path=".")
# Out:
# [youtube] Extracting URL: https://youtu.be/Rb7kZeztbf4?si=P1oxMCZUn84htNa1
# [youtube] Rb7kZeztbf4: Downloading webpage
# [youtube] Rb7kZeztbf4: Downloading ios player API JSON
# [youtube] Rb7kZeztbf4: Downloading mweb player API JSON
# [youtube] Rb7kZeztbf4: Downloading player 2d24ba15
# [youtube] Rb7kZeztbf4: Downloading m3u8 information
# [info] Rb7kZeztbf4: Downloading 1 format(s): 18
# [download] Destination: ./ap.mp4
# [download] 100% of    3.86MiB in 00:00:00 at 10.13MiB/s

# %%
# !pip install whisper
# !pip install git+https://github.com/openai/whisper.git
# !pip install ffmpeg-python
# !pip install googletrans==4.0.0-rc1
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for whisper: filename=whisper-1.1.10-py3-none-any.whl size=41120 sha256=dd4c2077640c7fb46b630b208c0292c72983232d38e8d8843dbc8b29af8b45ca
#   Stored in directory: /root/.cache/pip/wheels/aa/7c/1d/015619716e2facae6631312503baf3c3220e6a9a3508cb14b6
# Successfully built whisper
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-uyi_eyt2
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-uyi_eyt2
#   Resolved https://github.com/openai/whisper.git to commit 173ff7dd1d9fb1c4fddea0d41d704cfefeb8908c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 6.3 MB/s eta 0:00:00
# ...

# %%
# !sudo apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import whisper
import ffmpeg
from googletrans import Translator
import tempfile
from concurrent.futures import ThreadPoolExecutor

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("large")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def translate_text(text, target_language):
    """Translates text to the target language using Google Translate."""
    translator = Translator()
    translated = translator.translate(text, dest=target_language)
    return translated.text

def generate_srt(segments, srt_file, target_language=None):
    """Generates an SRT file from transcription segments."""
    with open(srt_file, "w") as file:
        with ThreadPoolExecutor() as executor:
            translations = list(executor.map(
                lambda seg: (seg, translate_text(seg['text'].strip(), target_language) if target_language else seg['text'].strip()),
                segments
            ))

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language}")
        else:
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, target_language)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"  # Replace with your video file path
    output_srt = "subtitlestrans_1_hi_google.srt"
    language = "en"  # Language code of the video
    target_language = "hi"  # Set to None for subtitles in the original language
    main(video_file, output_srt, language, target_language)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
import whisper
import ffmpeg
from googletrans import Translator
import tempfile
from concurrent.futures import ThreadPoolExecutor
import google.generativeai as genai
genai.configure(api_key="AIzaSyDahcDqQR0AJVlPg3F5onkZELNMxZkB_XM")

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("base")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

# def translate_text(text, target_language):
#     """Translates text to the target language using Google Translate."""
#     translator = Translator()
#     translated = translator.translate(text, dest=target_language)
#     return translated.text
def translate_text(text, target_language, context=""):
    """Translates text to the target language using Google Generative AI (Gemini)."""
    try:
        model = genai.GenerativeModel(
    'gemini-1.5-flash-001',
    generation_config=genai.GenerationConfig(
        # These are the default values for gemini-1.5-flash-001.
        temperature=1.0,
        top_k=64,
        top_p=0.95,
    ))

       chat = model.start_chat(history=[])
        response = chat.send_message(context)
        response = chat.send_message(text)

        return response.result.strip()
    except Exception as e:
        raise Exception(f"Gemini translation failed: {str(e)}")

def generate_srt(segments, srt_file, target_language=None, context=""):
    """Generates an SRT file from transcription segments with optional translation using Gemini."""
     with open(srt_file, "w") as file:
        with ThreadPoolExecutor() as executor:
            translations = list(executor.map(
                lambda seg: (seg, translate_text(seg['text'].strip(), target_language, context) if target_language else seg['text'].strip()),
                segments
            ))

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None, context=""):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language} with context: {context}")
        else:
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, target_language, context)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitlestrans.srt"
    language = "ja"  # Original language of the video
    target_language = "en"  # Target translation language
    context = "one piece episode keep it in mind while dubbing"  # Provide contextual info for better translation
    main(video_file, output_srt, language, target_language, context)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
import whisper
import ffmpeg
from concurrent.futures import ThreadPoolExecutor
import tempfile
import google.generativeai as genai

genai.configure(api_key="AIzaSyDahcDqQR0AJVlPg3F5onkZELNMxZkB_XM")

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("base")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def translate_text(text, target_language, context=""):
    """Translates text to the target language using Google Generative AI (Gemini) with provided context."""
    try:
         model = genai.GenerativeModel('gemini-1.5-flash')
         chat = model.start_chat(history=[])
         response = chat.send_message(context)
         response = chat.send_message(text)

         return response
    except Exception as e:
        raise Exception(f"Gemini translation failed: {str(e)}")

def generate_srt(segments, srt_file, target_language=None, context=""):
    """Generates an SRT file from transcription segments with optional translation."""
    with open(srt_file, "w") as file:
        with ThreadPoolExecutor(max_workers=5) as executor:
            translations = list(executor.map(
                lambda seg: (seg, translate_text(seg['text'], target_language, context) if target_language else seg['text']),
                segments
            ))

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None, context=""):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language} with context: {context}")
        else:
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, target_language, context)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitlestrans.srt"
    language = "ja"  # Original language of the video
    target_language = "en"  # Target translation language
    context = "One Piece anime episode, focusing on dialogues and dubbing instructions."
    main(video_file, output_srt, language, target_language, context)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyDahcDqQR0AJVlPg3F5onkZELNMxZkB_XM")

# %%
genai.configure(api_key="AIzaSyDahcDqQR0AJVlPg3F5onkZELNMxZkB_XM")

# %%
import whisper
import ffmpeg
from concurrent.futures import ThreadPoolExecutor
import tempfile
from transformers import MarianMTModel, MarianTokenizer

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("large")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def load_marian_model(source_lang, target_lang):
    """Loads MarianMT model and tokenizer for specified language pair."""
    model_name = f"Helsinki-NLP/opus-mt-{source_lang}-{target_lang}"
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)
    return model, tokenizer

def translate_text_marian(text, model, tokenizer):
    """Translates text using MarianMT."""
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    translated = model.generate(**inputs)
    return tokenizer.decode(translated[0], skip_special_tokens=True)

def generate_srt(segments, srt_file, model=None, tokenizer=None):
    """Generates an SRT file from transcription segments with optional translation using MarianMT."""
    with open(srt_file, "w") as file:
        with ThreadPoolExecutor(max_workers=5) as executor:
            translations = list(executor.map(
                lambda seg: (seg, translate_text_marian(seg['text'], model, tokenizer) if model else seg['text']),
                segments
            ))

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language}")
            source_lang = "ja"  # Source language (Japanese in this example)
            model, tokenizer = load_marian_model(source_lang, target_language)
        else:
            model = tokenizer = None
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, model, tokenizer)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitlestrans2_mar_hi.srt"
    language = "en"  # Original language of the video
    target_language = "hi"  # Target translation language (English)
    main(video_file, output_srt, language, target_language)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
# !pip install sacremoses
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 10.1 MB/s eta 0:00:00
# ...

# %%
import whisper
import ffmpeg
from concurrent.futures import ThreadPoolExecutor
import tempfile
from transformers import BartForConditionalGeneration, BartTokenizer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("base")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def load_bart_model(target_lang):
    """Loads BART-MT model and tokenizer for the target language."""
    model_name="facebook/mbart-large-50-many-to-many-mmt"  # Many-to-one (source -> target)
    tokenizer = AutoTokenizer.from_pretrained("facebook/mbart-large-50-many-to-many-mmt", src_lang="en_XX", tgt_lang=target_language)

    model = AutoModelForSeq2SeqLM.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
    return model, tokenizer

def translate_text_bart(text, model, tokenizer):
    """Translates text using BART-MT."""
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    translated = model.generate(**inputs)
    return tokenizer.decode(translated[0], skip_special_tokens=True)

# def generate_srt(segments, srt_file, model=None, tokenizer=None):
#     """Generates an SRT file from transcription segments with optional translation using BART-MT."""
#     with open(srt_file, "w") as file:
#         with ThreadPoolExecutor(max_workers=5) as executor:
#             translations = list(executor.map(
#                 lambda seg: (seg, translate_text_bart(seg['text'], model, tokenizer) if model else seg['text']),
#                 segments
#             ))

#         for i, (segment, text) in enumerate(translations):
#             start_time = format_time(segment['start'])
#             end_time = format_time(segment['end'])
#             file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")
def generate_srt(segments, srt_file, target_language=None):
    """Generates an SRT file from transcription segments with optional translation using BART-MT."""
    with open(srt_file, "w") as file:
        with ThreadPoolExecutor(max_workers=5) as executor:
            translations = list(
                executor.map(
                    lambda seg: translate_segment(seg, target_language),
                    segments
                )
            )

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def translate_segment(segment, target_language):
    """Handles translation of a single segment with a fresh BART instance."""
    if target_language:
        model, tokenizer = load_bart_model(target_language)
        text = translate_text_bart(segment['text'], model, tokenizer)
    else:
        text = segment['text']
    return segment, text

def main(video_file, output_srt, language, target_language=None):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language}")
            model, tokenizer = load_bart_model(target_language)
        else:
            model = tokenizer = None
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, tokenizer)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitlestrans_bart3.srt"
    language = "en"  # Original language of the video
    target_language = "en"  # Target translation language (English)
    main(video_file, output_srt, language, target_language)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
import whisper
import ffmpeg
from concurrent.futures import ThreadPoolExecutor
import tempfile
from transformers import AutoTokenizer, AutoModelForCausalLM

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("base")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def load_llama_model():
    """Loads the LLaMA 2 model and tokenizer for translation."""
    model_name = "meta-llama/Llama-3.1-8B-Instruct"  # Replace with a smaller LLaMA model if needed
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    return model, tokenizer

def translate_text_llama(text, model, tokenizer, context=""):
    """Translates text using Meta's LLaMA 2 with contextual understanding."""
    try:
        prompt = f"Context: {context}\nTranslate the following text:\n{text}"
        inputs = tokenizer(prompt, return_tensors="pt", truncation=True, padding=True)
        output = model.generate(**inputs, max_length=512)
        translated_text = tokenizer.decode(output[0], skip_special_tokens=True).split("\n")[-1]  # Extract last line
        return translated_text
    except Exception as e:
        raise Exception(f"LLaMA translation failed: {str(e)}")

def generate_srt(segments, srt_file, model=None, tokenizer=None, context=""):
    """Generates an SRT file from transcription segments with optional translation using LLaMA."""
    with open(srt_file, "w") as file:
        with ThreadPoolExecutor(max_workers=5) as executor:
            translations = list(executor.map(
                lambda seg: (seg, translate_text_llama(seg['text'], model, tokenizer, context) if model else seg['text']),
                segments
            ))

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None, context=""):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language} with context: {context}")
            model, tokenizer = load_llama_model()
        else:
            model = tokenizer = None
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, model, tokenizer, context)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitles_llama.srt"
    language = "en"  # Original language of the video
    target_language = "en"  # Target translation language
    context = "friends episode."
    main(video_file, output_srt, language, target_language, context)
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 78.2MiB/s]
# ...

# %%
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
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b41d4bcbd813> in <cell line: 1>()
# ----> 1 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
#
# NameError: name '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' is not defined

# %%
# !pip install transformers huggingface_hub

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")
print("Model loaded successfully!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Model loaded successfully!

# %%
import whisper
import ffmpeg
from concurrent.futures import ThreadPoolExecutor
import tempfile
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("base")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def load_bart_model(target_language):
    """Loads BART-MT model and tokenizer for the target language."""
    model_name = "facebook/mbart-large-50-many-to-many-mmt"
    tokenizer = AutoTokenizer.from_pretrained(model_name, src_lang="en_XX", tgt_lang=f"{target_language}")
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    return model, tokenizer

def translate_text_bart(text, model, tokenizer):
    """Translates text using BART-MT."""
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    translated = model.generate(**inputs)
    return tokenizer.decode(translated[0], skip_special_tokens=True)

def generate_srt(segments, srt_file, model=None, tokenizer=None):
    """Generates an SRT file from transcription segments with optional translation using BART-MT."""
    with open(srt_file, "w") as file:
        for i, segment in enumerate(segments):
            text = translate_text_bart(segment['text'], model, tokenizer) if model else segment['text']
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        model, tokenizer = (None, None)
        if target_language:
            print(f"Translating subtitles to: {target_language}")
            model, tokenizer = load_bart_model(target_language)
        else:
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, model, tokenizer)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitlestrans_bart3_hi.srt"
    language = "en"  # Original language of the video
    target_language = "hi_IN"  # Example: Translate to French
    main(video_file, output_srt, language, target_language)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
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

# %%
import whisper
import ffmpeg
from concurrent.futures import ThreadPoolExecutor
import tempfile
from transformers import AutoTokenizer, AutoModelForCausalLM

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("base")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def load_gemma_model():
    """Loads the Gemma model and tokenizer for translation."""
    model_name = "google/gemma-2-9b"  # Replace with the actual Gemma model name
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    return model, tokenizer

def translate_text_gemma(text, model, tokenizer, context=""):
    """Translates text using Gemma with contextual understanding."""
    try:
        prompt = f"Context: {context}\nTranslate the following text:\n{text}"
        inputs = tokenizer(prompt, return_tensors="pt", truncation=True, padding=True)
        output = model.generate(**inputs, max_length=512)
        translated_text = tokenizer.decode(output[0], skip_special_tokens=True).split("\n")[-1]  # Extract last line
        return translated_text
    except Exception as e:
        raise Exception(f"Gemma translation failed: {str(e)}")

def generate_srt(segments, srt_file, model=None, tokenizer=None, context=""):
    """Generates an SRT file from transcription segments with optional translation using Gemma."""
    with open(srt_file, "w") as file:
        with ThreadPoolExecutor(max_workers=5) as executor:
            translations = list(executor.map(
                lambda seg: (seg, translate_text_gemma(seg['text'], model, tokenizer, context) if model else seg['text']),
                segments
            ))

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None, context=""):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language} with context: {context}")
            model, tokenizer = load_gemma_model()
        else:
            model = tokenizer = None
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, model, tokenizer, context)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitles_gemma.srt"
    language = "en"  # Original language of the video
    target_language = "hi"  # Target translation language
    context = "Friends episode."
    main(video_file, output_srt, language, target_language, context)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
import whisper
import ffmpeg
from concurrent.futures import ThreadPoolExecutor
import tempfile
import requests

def extract_audio(video_file, audio_file):
    """Extracts audio from video."""
    ffmpeg.input(video_file).output(audio_file, acodec='pcm_s16le', ac=1, ar='16000').run(overwrite_output=True)

def transcribe_audio(audio_file, language):
    """Transcribes audio to text using Whisper in the specified language."""
    model = whisper.load_model("base")
    result = model.transcribe(audio_file, language=language)
    return result['segments']

def format_time(seconds):
    """Formats time from seconds to SRT format (hh:mm:ss,ms)."""
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02},{milliseconds:03}"

def translate_text_groq(text, source_lang, target_lang, context=""):
    """Translates text using Groq API."""
    url = "https://api.groq.com/v1/translate"  # Replace with actual Groq API URL
    payload = {
        "text": text,
        "source_language": source_lang,
        "target_language": target_lang,
        "context": context
    }
    headers = {
        "Authorization": "Bearer YOUR_GROQ_API_KEY",  # Replace with your API key
        "Content-Type": "application/json"
    }

    response = requests.post(url, json=payload, headers=headers)

    if response.status_code == 200:
        return response.json().get("translated_text", text)
    else:
        raise Exception(f"Groq API translation failed: {response.text}")

def generate_srt(segments, srt_file, source_lang, target_lang=None, context=""):
    """Generates an SRT file from transcription segments with optional translation using Groq API."""
    with open(srt_file, "w") as file:
        with ThreadPoolExecutor(max_workers=5) as executor:
            translations = list(executor.map(
                lambda seg: (seg, translate_text_groq(seg['text'], source_lang, target_lang, context) if target_lang else seg['text']),
                segments
            ))

        for i, (segment, text) in enumerate(translations):
            start_time = format_time(segment['start'])
            end_time = format_time(segment['end'])
            file.write(f"{i + 1}\n{start_time} --> {end_time}\n{text}\n\n")

def main(video_file, output_srt, language, target_language=None, context=""):
    with tempfile.TemporaryDirectory() as tempdir:
        audio_file = f"{tempdir}/extracted_audio.wav"
        extract_audio(video_file, audio_file)
        segments = transcribe_audio(audio_file, language)

        if target_language:
            print(f"Translating subtitles to: {target_language} with context: {context}")
        else:
            print(f"Generating subtitles in the original language: {language}")

        generate_srt(segments, output_srt, language, target_language, context)
        print(f"Subtitle file '{output_srt}' generated successfully.")

if __name__ == "__main__":
    video_file = "ap.mp4"
    output_srt = "subtitles_groq.srt"
    language = "en"  # Original language of the video
    target_language = "hi"  # Target translation language
    context = "Friends episode."
    main(video_file, output_srt, language, target_language, context)
